# %%
import os
import pandas as pd

# os.listdir('./dirve/MyDrive/ml_data')

# base_src=./dirve/MyDrive/ml_data

# friend_src= base_src + '/friend.csv'
# new_friend_src =base_src+'/new_friend.csv'
friend_src='friend.csv'
new_friend_src='new_friend.csv'

# %% [markdown]
# # 새 섹션

# %%
df = pd.read_csv(friend_src, encoding='utf-8')
df.head(6)
df.to_csv(new_friend_src, index=False, encoding='utf-8')
#인덱스 -> 조회,정렬

# %%
series = df['name']
series

# %%
#pd.Series의 옵션이 무엇이 있는지 확인
# index => 할당값의 지정지이름, 중복가능
# dtype => int, float, string, boolean

series= pd.Series([10,2,5,4],index=['a','b','c','d'],dtype=float)
series.sort_values(ascending=True)
#ascending 디폴트, ascending=False ->내림차순

# %%
#DataFrame 실습
df = pd.DataFrame({'a':[2,3],'b':[5,10]})
df = pd.DataFrame([[2,5],[2,10],[10,20]], columns=['a','b',])
df

# %%
# - DataFrame 행,열 선택 및 필터링
df= pd.read_csv(friend_src,encoding='utf-8')
df.head()

# %%
df.iloc[4]

# %%
df.iloc[[2]]

# %%
df['age']

# %%
df.iloc[:,2]

# %%
df.loc[:,'job']

# %%
df.loc[1,'job']

# %%
df.iloc[1,2]

# %%
a={'a':1,'b':2,'c':3,'d':4}

# %% [markdown]
# iloc VS loc
# iloc는 인덱스와 컬럼을 리스트 배열로 선택
# loc 는 인덱스와 컬럼을 문자로 선택하는 것
